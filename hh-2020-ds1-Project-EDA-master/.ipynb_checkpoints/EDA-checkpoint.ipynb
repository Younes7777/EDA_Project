# %% [markdown]
# ![titel](dataset-original.jpg)

# %% [markdown]
# <font size="7">King County Housing analysis</font>

# %% [markdown]
# **<font size="4">objecitves</font>**:
# * Three recommendations for home sellers and/or buyers in King County
# * Model this dataset with a multivariate linear regression to predict the sale price of houses

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Preparing-Data" data-toc-modified-id="Preparing-Data-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Preparing Data</a></span><ul class="toc-item"><li><span><a href="#Importing-fundamental-data-exploration-libaries" data-toc-modified-id="Importing-fundamental-data-exploration-libaries-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Importing fundamental data exploration libaries</a></span></li><li><span><a href="#Importing-the-data-and-join-them-to-the-geo-data-von--US-Zip-Code-Latitude-and-Longitude" data-toc-modified-id="Importing-the-data-and-join-them-to-the-geo-data-von--US-Zip-Code-Latitude-and-Longitude-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Importing the data and join them to the geo-data von  <a href="https://public.opendatasoft.com/explore/dataset/us-zip-code-latitude-and-longitude/table/?q=wa&amp;refine.state=WA" target="_blank">US Zip Code Latitude and Longitude</a></a></span></li><li><span><a href="#Clean-Data" data-toc-modified-id="Clean-Data-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Clean Data</a></span></li></ul></li><li><span><a href="#Exploratory-data-analysis" data-toc-modified-id="Exploratory-data-analysis-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Exploratory data analysis</a></span><ul class="toc-item"><li><span><a href="#the-relationship-between-price-and-all-categorical-variables-in-the-data" data-toc-modified-id="the-relationship-between-price-and-all-categorical-variables-in-the-data-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>the relationship between price and all categorical variables in the data</a></span><ul class="toc-item"><li><span><a href="#The-relationship-between-number-of-bedromms-and-price" data-toc-modified-id="The-relationship-between-number-of-bedromms-and-price-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>The relationship between number of bedromms and price</a></span></li><li><span><a href="#The-relationship-between-number-of-bathrooms-and-price" data-toc-modified-id="The-relationship-between-number-of-bathrooms-and-price-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>The relationship between number of bathrooms and price</a></span></li><li><span><a href="#The-relationship-between-number-of-floors-and-price" data-toc-modified-id="The-relationship-between-number-of-floors-and-price-2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>The relationship between number of floors and price</a></span></li><li><span><a href="#The-relationship-between-waterfront-and-price" data-toc-modified-id="The-relationship-between-waterfront-and-price-2.1.4"><span class="toc-item-num">2.1.4&nbsp;&nbsp;</span>The relationship between waterfront and price</a></span></li><li><span><a href="#The-relationship-between-view-and-price" data-toc-modified-id="The-relationship-between-view-and-price-2.1.5"><span class="toc-item-num">2.1.5&nbsp;&nbsp;</span>The relationship between view and price</a></span></li><li><span><a href="#The-relationship-between-condition-and-price" data-toc-modified-id="The-relationship-between-condition-and-price-2.1.6"><span class="toc-item-num">2.1.6&nbsp;&nbsp;</span>The relationship between condition and price</a></span></li><li><span><a href="#The-relationship-between-grade-and-price" data-toc-modified-id="The-relationship-between-grade-and-price-2.1.7"><span class="toc-item-num">2.1.7&nbsp;&nbsp;</span>The relationship between grade and price</a></span></li><li><span><a href="#The-relationship-between-built-year-and-price" data-toc-modified-id="The-relationship-between-built-year-and-price-2.1.8"><span class="toc-item-num">2.1.8&nbsp;&nbsp;</span>The relationship between built year and price</a></span></li><li><span><a href="#The-relationship-between-city-and-price" data-toc-modified-id="The-relationship-between-city-and-price-2.1.9"><span class="toc-item-num">2.1.9&nbsp;&nbsp;</span>The relationship between city and price</a></span></li></ul></li><li><span><a href="#the-relationship-between-price-and-all-continuous-variables-in-the-data" data-toc-modified-id="the-relationship-between-price-and-all-continuous-variables-in-the-data-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>the relationship between price and all continuous variables in the data</a></span><ul class="toc-item"><li><span><a href="#scatter-plot-matrix" data-toc-modified-id="scatter-plot-matrix-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>scatter plot matrix</a></span></li><li><span><a href="#Correlation-Matrix" data-toc-modified-id="Correlation-Matrix-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Correlation Matrix</a></span></li></ul></li></ul></li><li><span><a href="#My-recommendations-based-on-the-exploratory-data-analysis" data-toc-modified-id="My-recommendations-based-on-the-exploratory-data-analysis-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>My recommendations based on the exploratory data analysis</a></span></li><li><span><a href="#Prediction-of-Price-by-regression-analysis" data-toc-modified-id="Prediction-of-Price-by-regression-analysis-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Prediction of Price by regression analysis</a></span><ul class="toc-item"><li><span><a href="#regression-analysis" data-toc-modified-id="regression-analysis-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>regression analysis</a></span></li><li><span><a href="#Prediction" data-toc-modified-id="Prediction-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Prediction</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Preparing Data

# %% [markdown]
# This dataset contains house sale prices for King County. It includes homes sold between May 2014 and May 2015 and the following features:
# * **id** - unique identified for a house
# * **dateDate** - house was sold
# * **pricePrice** -  is prediction target
# * **bedroomsNumber** -  of Bedrooms/House
# * **bathroomsNumber** -  of bathrooms/bedrooms
# * **sqft_livingsquare** -  footage of the home
# * **sqft_lotsquare** -  footage of the lot
# * **floorsTotal** -  floors (levels) in house
# * **waterfront** - House which has a view to a waterfront
# * **view** - Has been viewed
# * **condition** - How good the condition is ( Overall )
# * **grade** - overall grade given to the housing unit, based on King County grading system
# * **sqft_above** - square footage of house apart from basement
# * **sqft_basement** - square footage of the basement
# * **yr_built** - Built Year
# * **yr_renovated** - Year when house was renovated
# * **zipcode** - zip
# * **lat** - Latitude coordinate
# * **long** - Longitude coordinate
# * **sqft_living15** - The square footage of interior housing living space for the nearest 15 neighbors
# * **sqft_lot15** - The square footage of the land lots of the nearest 15 neighbors

# %% [markdown]
# ## Importing fundamental data exploration libaries

# %%
import math
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.sandbox.regression.predstd import wls_prediction_std
from sklearn import preprocessing
np.set_printoptions(suppress=True)
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
# %matplotlib inline

# %% [markdown]
# ## Importing the data and join them to the geo-data von  [US Zip Code Latitude and Longitude](https://public.opendatasoft.com/explore/dataset/us-zip-code-latitude-and-longitude/table/?q=wa&refine.state=WA)

# %%
data_ = pd.read_csv('King_County_House_prices_dataset.csv')
state_geo='us-zip-code-latitude-and-longitude .geojson'
geo_data= gpd.read_file(state_geo)[["zip","city"]]

geo_data.rename(columns = {'zip':'zipcode'}, inplace = True)
geo_data['zipcode']=geo_data['zipcode'].astype('int')
data=pd.merge(data_,geo_data,on='zipcode', how='left')

# %%
data.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# 0      5650     1.0         NaN   0.0  ...        1180            0.0
# 1      7242     2.0         0.0   0.0  ...        2170          400.0
# 2     10000     1.0         0.0   0.0  ...         770            0.0
# 3      5000     1.0         0.0   0.0  ...        1050          910.0
# 4      8080     1.0         0.0   0.0  ...        1680            0.0
#
#    yr_built yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %% [markdown]
# ## Clean Data

# %%
data['waterfront']=data.waterfront.astype('category')
data['view']=data.view.astype('category')
data['condition']=data.condition.astype('category')
data['grade']=data.grade.astype('category')

# %%
missing = pd.DataFrame(data.isnull().sum(),columns=['Number'])
missing['Percentage'] = round(missing.Number/data.shape[0],2)
missing
# Out:
#                Number  Percentage
# id                  0        0.00
# date                0        0.00
# price               0        0.00
# bedrooms            0        0.00
# bathrooms           0        0.00
# sqft_living         0        0.00
# sqft_lot            0        0.00
# floors              0        0.00
# waterfront       2376        0.11
# view               63        0.00
# condition           0        0.00
# grade               0        0.00
# sqft_above          0        0.00
# sqft_basement       0        0.00
# yr_built            0        0.00
# yr_renovated     3842        0.18
# zipcode             0        0.00
# lat                 0        0.00
# long                0        0.00
# sqft_living15       0        0.00
# sqft_lot15          0        0.00
# city              198        0.01

# %%
data.replace(to_replace=['?', ''], value='NaN', inplace=True)
data['sqft_basement'] = data['sqft_basement'].astype(float)

# %% [markdown]
# # Exploratory data analysis

# %% [markdown]
# ## the relationship between price and all categorical variables in the data

# %% [markdown]
# ### The relationship between number of bedromms and price

# %%
plt.subplots(figsize=(10,5))
sns.boxplot(x='bedrooms', y="price", data=data, showmeans = True)
plt.show()

# %% [markdown]
# ### The relationship between number of bathrooms and price

# %%
plt.subplots(figsize=(10,5))
sns.boxplot(x='bathrooms', y="price", data=data, showmeans = True)
plt.show()

# %% [markdown]
# ### The relationship between number of floors and price

# %%
plt.subplots(figsize=(10,5))
sns.boxplot(x='floors', y="price", data=data,  showmeans = True)
plt.show()

# %% [markdown]
# ### The relationship between waterfront and price

# %%
plt.subplots(figsize=(10,5))
sns.boxplot(x='waterfront', y="price", data=data,  showmeans = True)
plt.show()

# %% [markdown]
# ### The relationship between view and price

# %%
plt.subplots(figsize=(10,5))
sns.boxplot(x='view', y="price", data=data, showmeans = True)
#plt.show()

# %% [markdown]
# ### The relationship between condition and price

# %%
plt.subplots(figsize=(10,5))
sns.boxplot(x='condition', y="price", data=data, showmeans = True)
#plt.show()

# %% [markdown]
# ### The relationship between grade and price

# %%
plt.subplots(figsize=(10,5))
sns.boxplot(x='grade', y="price", data=data, showmeans = True)
#plt.show()

# %% [markdown]
# ### The relationship between built year and price

# %%
plt.subplots(figsize=(26,10))
chart1=sns.boxplot(x="yr_built", y="price", data=data, showmeans = True)
chart1.set_xticklabels(chart1.get_xticklabels(), rotation=90)
plt.show()

# %% [markdown]
# ### The relationship between city and price

# %%
plt.subplots(figsize=(10,5))
chart=sns.boxplot(x='city', y="price", data=data, showmeans = True)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45)
plt.show()

# %% [markdown]
# * **almost all of the ordinal parameters (bedrooms, bathrooms, floors, views, grade) were also moderately to strongly associated with price**.
# * **The prices are particularly high in Medina, since with an average per capita income of USD 81,742 it is considered extremely wealthy**.
# * **In Auburn the prices are also expensive, because this city is the home to a number of major companies including Northwest Territorial Mint, ZONES, Toysmith, Timberland Homes, POE construction, Armstrong Construction, Miles Sand and Gravel, Oak Harbor Freight Lines**.
# * **Interestingly enough, one would expect a linear relationship with newer houses being significantly more expensive. However, this is not the case, as seen by the graph**.

# %% [markdown]
# ## the relationship between price and all continuous variables in the data

# %% [markdown]
# ### scatter plot matrix

# %%
sns.set()
cols = ['price', 'sqft_living','sqft_lot','floors', 'sqft_above','sqft_basement',  'yr_built','sqft_living15','sqft_lot15']
sns.pairplot(data[cols], size = 2.5)
plt.show()
# Out:
# /Users/younesiferd/opt/anaconda3/envs/nf/lib/python3.6/site-packages/seaborn/axisgrid.py:2071: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### Correlation Matrix

# %%
df_ = data.drop(["id"], axis =1)
df_=df_[['price', 'sqft_living','sqft_lot','floors', 'sqft_above','sqft_basement',  'yr_built','sqft_living15','sqft_lot15']]
mask = np.triu(df_.corr())
ax = sns.heatmap(round(df_.corr()*100,0)
                 ,annot=True
                 ,mask=mask
                 ,cmap='coolwarm')

# %% [markdown]
# **Okay, so the features: square foot living area, square feet abouve the ground level and sqft_15 features displayed the highest correlation wih the price of the house.¶**

# %% [markdown]
# # My recommendations based on the exploratory data analysis

# %% [markdown]
# * **new built houses are not necessarily expensive**
# * **if you want to buy a house with good construction and design, look at the index first, if it is available**
# * **If you want to buy a cheap house, avoid cities with water views and wealthy cities like Medina**

# %% [markdown]
# # Prediction of Price by regression analysis

# %% [markdown]
# ## regression analysis

# %% [markdown]
# we logarithmise the price

# %%
data['price']=np.log(data['price'])
sns.distplot(data['price'], hist=True, kde=True)

# %% [markdown]
# we create dummy variables for categorial features

# %%
dummy1=pd.get_dummies(data['waterfront'],prefix='waterfront')
dummy2=pd.get_dummies(data['view'],prefix='view')
dummy3=pd.get_dummies(data['condition'],prefix='condition')
data=pd.concat([data,dummy1,dummy2,dummy3], axis=1)

# %%
data=data.dropna()
X=data[['bedrooms','bathrooms','sqft_living','sqft_lot','floors','yr_built','yr_renovated','grade','sqft_above','sqft_basement','sqft_living15','sqft_lot15','waterfront_1.0','view_0.0','view_2.0','view_3.0','view_4.0','condition_2','condition_3','condition_4','condition_5','yr_renovated','yr_built']]
y=data[["price"]]

# %% [markdown]
# we now fit our model

# %%
X = sm.add_constant(X)
# Out:
# /Users/younesiferd/opt/anaconda3/envs/nf/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %%
model = sm.OLS(y, X)
results = model.fit()

# %%
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.655
# Model:                            OLS   Adj. R-squared:                  0.654
# Method:                 Least Squares   F-statistic:                     1446.
# Date:                Sun, 14 Jun 2020   Prob (F-statistic):               0.00
# Time:                        18:53:13   Log-Likelihood:                -3773.2
# No. Observations:               15275   AIC:                             7588.
# Df Residuals:                   15254   BIC:                             7749.
# Df Model:                          20
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             21.6755      0.242     89.643      0.000      21.202      22.149
# ...

# %% [markdown]
# ## Prediction

# %% [markdown]
# Let us split our data into trainig and test datasets, we will use 80% of the data for training and the rest for testing

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
regressor = LinearRegression()  
regressor.fit(X_train, y_train) #training the algorithm
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(regressor.intercept_)
# Out:
# [21.51369404]

# %%
print(regressor.coef_)
# Out:
# [[ 0.         -0.02502936  0.07419149  0.00010272  0.00000014  0.11444412
#   -0.00272337  0.00000921  0.20087786  0.00001306  0.00008966  0.00010395
#   -0.00000038  0.31706539 -0.14948976 -0.07311402 -0.05571837  0.01944118
#   -0.01366119  0.14921918  0.1600613   0.23232034  0.00000921 -0.00272337]]

# %%
# Look at predictions on training and validation set
y_train_pred = regressor.predict(X_train)
y_test_pred  = regressor.predict(X_test)
print('RMSE on Training set:', np.sqrt(metrics.mean_squared_error(y_train, y_train_pred)))
print('RMSE on Test set:', np.sqrt(metrics.mean_squared_error(y_test, y_test_pred)))
# Out:
# RMSE on Training set: 0.30903129988680933
# RMSE on Test set: 0.313125697895228

# %%
# Plot predictions
plt.scatter(y_train_pred, y_train, c = "blue", marker = "s", label = "Training data")
plt.scatter(y_test_pred, y_test, c = "lightgreen", marker = "s", label = "Validation data")
plt.title("Linear regression")
plt.xlabel("Predicted values")
plt.ylabel("Real values")
plt.legend(loc = "upper left")
plt.plot([11.5, 15.5], [11.5, 15.5], c = "red")
plt.show()
